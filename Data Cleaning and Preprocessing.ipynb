# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_excel('G:\personal\ML Exercise\OUP_long_MF1564_v1.xls')

# %%
dataset
# Out:
#      Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 0           NaN        NaN  Educational Attainment for Total Population, 1...
# 1           NaN        NaN                                                NaN
# 2           NaN        NaN                                                NaN
# 3           NaN        NaN                                                NaN
# 4           NaN        NaN                                                NaN
# 5           NaN        NaN                                                NaN
# 6       Country       Year                                          Age Group
# 7           NaN        NaN                                                NaN
# 8           NaN        NaN                                                NaN
# 9           NaN        NaN                                                NaN
# 10          NaN        NaN                                                NaN
# ...

# %%
dataset.shape
# Out:
# (2946, 17)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2946 entries, 0 to 2945
# Data columns (total 17 columns):
# Unnamed: 0     90 non-null object
# Unnamed: 1     2582 non-null object
# Unnamed: 2     2583 non-null object
# Unnamed: 3     2581 non-null float64
# Unnamed: 4     2582 non-null object
# Unnamed: 5     2585 non-null object
# Unnamed: 6     2582 non-null object
# Unnamed: 7     2583 non-null object
# Unnamed: 8     2582 non-null object
# Unnamed: 9     2583 non-null object
# Unnamed: 10    2582 non-null object
# Unnamed: 11    2582 non-null object
# Unnamed: 12    2582 non-null object
# Unnamed: 13    2582 non-null object
# Unnamed: 14    2582 non-null object
# Unnamed: 15    2584 non-null object
# Unnamed: 16    2582 non-null object
# dtypes: float64(1), object(16)
# memory usage: 391.3+ KB

# %%
dataset.columns=dataset.columns.str.strip()

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
dataset['Unnamed: 0'].value_counts(dropna=False)
# Out:
# NaN                   2856
# Argentina                1
# Tunisia                  1
# Benin                    1
# Ireland                  1
# Costa Rica               1
# Malta                    1
# Taiwan                   1
# Sierra Leone             1
# Cameroon                 1
# United Kingdom           1
# Guatemala                1
# Barbados                 1
# Zimbabwe                 1
# Brazil                   1
# Luxembourg               1
# Greece                   1
# Dominican Rep.           1
# Peru                     1
# Russian Federation       1
# Uruguay                  1
# Bulgaria                 1
# Algeria                  1
# Malaysia                 1
# Sudan                    1
# New Zealand              1
# China                    1
# Thailand                 1
# Uganda                   1
# Mauritius                1
#                       ...
# Syria                    1
# Norway                   1
# Guyana                   1
# ...

# %%
dataset.dropna(subset=['Unnamed: 0'], inplace=True)

# %%
dataset
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4  \
# 6                 Country       Year  Age Group         NaN  No Schooling
# 13              Australia       1870         15        64.0          50.5
# 46                Austria       1870         15        64.0          62.7
# 79                Belgium       1870         15        64.0          44.2
# 112                Canada       1870         15        64.0          29.2
# 145               Denmark       1870         15        64.0          13.7
# 178               Finland       1870         15        64.0          96.3
# 211                France       1870         15        64.0          78.4
# 244               Germany       1870         15        64.0          65.5
# 277                Greece       1870         15        64.0          82.4
# 310               Ireland       1870         15        64.0          81.9
# 343                 Italy       1870         15        64.0          71.9
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90 entries, 6 to 2917
# Data columns (total 17 columns):
# Unnamed: 0     90 non-null object
# Unnamed: 1     90 non-null object
# Unnamed: 2     90 non-null object
# Unnamed: 3     89 non-null float64
# Unnamed: 4     90 non-null object
# Unnamed: 5     90 non-null object
# Unnamed: 6     89 non-null object
# Unnamed: 7     89 non-null object
# Unnamed: 8     89 non-null object
# Unnamed: 9     89 non-null object
# Unnamed: 10    89 non-null object
# Unnamed: 11    90 non-null object
# Unnamed: 12    90 non-null object
# Unnamed: 13    90 non-null object
# Unnamed: 14    90 non-null object
# Unnamed: 15    90 non-null object
# Unnamed: 16    90 non-null object
# dtypes: float64(1), object(16)
# memory usage: 12.7+ KB

# %%
dataset.dropna(axis=1,inplace=True)

# %%
dataset.shape
# Out:
# (90, 11)

# %%
dataset
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2    Unnamed: 4  \
# 6                 Country       Year  Age Group  No Schooling
# 13              Australia       1870         15          50.5
# 46                Austria       1870         15          62.7
# 79                Belgium       1870         15          44.2
# 112                Canada       1870         15          29.2
# 145               Denmark       1870         15          13.7
# 178               Finland       1870         15          96.3
# 211                France       1870         15          78.4
# 244               Germany       1870         15          65.5
# 277                Greece       1870         15          82.4
# 310               Ireland       1870         15          81.9
# 343                 Italy       1870         15          71.9
# 376                 Japan       1870         15          73.2
# 409            Luxembourg       1870         15          99.2
# ...

# %%
dataset.columns=['Country','Year','Age Group','No Schooling','Highest level attained', 'Avg. Years of Total Schooling','Avg. Years of Primary Schooling','Avg. Years of Secondary Schooling'
                
                ,'Avg. Years of Tertiary Schooling','Population(1000s)','Region']

# %%
dataset.columns
# Out:
# Index(['Country', 'Year', 'Age Group', 'No Schooling',
#        'Highest level attained', 'Avg. Years of Total Schooling',
#        'Avg. Years of Primary Schooling', 'Avg. Years of Secondary Schooling',
#        'Avg. Years of Tertiary Schooling', 'Population(1000s)', 'Region'],
#       dtype='object')

# %%
dataset
# Out:
#                   Country  Year  Age Group  No Schooling  \
# 6                 Country  Year  Age Group  No Schooling
# 13              Australia  1870         15          50.5
# 46                Austria  1870         15          62.7
# 79                Belgium  1870         15          44.2
# 112                Canada  1870         15          29.2
# 145               Denmark  1870         15          13.7
# 178               Finland  1870         15          96.3
# 211                France  1870         15          78.4
# 244               Germany  1870         15          65.5
# 277                Greece  1870         15          82.4
# 310               Ireland  1870         15          81.9
# 343                 Italy  1870         15          71.9
# 376                 Japan  1870         15          73.2
# 409            Luxembourg  1870         15          99.2
# 442           Netherlands  1870         15            28
# ...

# %%
dataset.drop([6],axis=0,inplace=True)

# %%
dataset
# Out:
#                   Country  Year Age Group No Schooling Highest level attained  \
# 13              Australia  1870        15         50.5                   49.3
# 46                Austria  1870        15         62.7                   36.5
# 79                Belgium  1870        15         44.2                   52.9
# 112                Canada  1870        15         29.2                   68.2
# 145               Denmark  1870        15         13.7                   83.9
# 178               Finland  1870        15         96.3                    3.7
# 211                France  1870        15         78.4                   21.6
# 244               Germany  1870        15         65.5                   27.3
# 277                Greece  1870        15         82.4                     16
# 310               Ireland  1870        15         81.9                     18
# 343                 Italy  1870        15         71.9                   27.8
# ...
